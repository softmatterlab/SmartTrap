# %%
import sys
sys.path.append("..")
from motor_controls import TestMotorController

# %% [markdown]
# # Create a test motor controller

# %%
m = TestMotorController()
m.set_speed(50)
m.move_to_location([0, 0, 0])
m.move_at_speed(1, -2, 0.5)  # integrates ~1 s step
print(m.get_x_position(), m.get_y_position(), m.get_z_position())

m.move_to_location([1, 10, -10])
print(m.get_x_position(), m.get_y_position(), m.get_z_position())
# Out:
# Moving to location [0, 0, 0]
# Moving at speed x: 1, y: -2, z: 0.5
# 1 -2 0.5
# Moving to location [1, 10, -10]
# 1 10 -10
